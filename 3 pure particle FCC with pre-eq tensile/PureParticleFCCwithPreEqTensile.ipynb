# %% [markdown]
# # Pure Particle FCC with Pre-Equilibrium and run tensil test
#
# ## Domain Creation
# the following procedures include 3 parts of lammps source files:
# * create_box.lmps
# * run_pre-equilbrium.lmps

# %%
import subprocess
#create a box full of atoms
subprocess.call(['lmp_serial', '-in', 'create_box.lmps'])
# Out:
# LAMMPS (2 Aug 2023)
# Lattice spacing in x,y,z = 0.0002 0.0002 0.0002
# Created orthogonal box = (-0.01 -0.01 -0.01) to (0.01 0.01 0.01)
#   1 by 1 by 1 MPI processor grid
# Created 66325 atoms
#   using lattice units in orthogonal box = (-0.01 -0.01 -0.01) to (0.01 0.01 0.01)
#   create_atoms CPU = 0.003 seconds
# System init for write_data ...
# WARNING: Communication cutoff is 0.0. No ghost atoms will be generated. Atoms may get lost. (src/comm_brick.cpp:210)
# Total wall time: 0:00:00
# 0

# %% [markdown]
# ![](./box-full-of-atoms.png)

# %% [markdown]
# ## Run pre-equilibrium process
# for standard procedures, the process is necessary to check if the system is in equillibrium and stable.

# %%
return_code = subprocess.call(['mpirun', '-np', '4', 'lmp_mpi', '-pk', 'omp', '4', '-in', 'run_pre-equilibrium.lmps'])
# Out:
# LAMMPS (2 Aug 2023)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:98)
#   using 1 OpenMP thread(s) per MPI task
# set 4 OpenMP thread(s) per MPI task
# using multi-threaded neighbor list subroutines
# Lattice spacing in x,y,z = 0.0002 0.0002 0.0002
# Reading data file ...
#   orthogonal box = (-0.01 -0.01 -0.01) to (0.01 0.01 0.01)
#   1 by 2 by 2 MPI processor grid
#   reading atoms ...
#   66325 atoms
#   reading velocities ...
#   66325 velocities
#   read_data CPU = 0.098 seconds
# Generated 0 of 0 mixed pair_coeff terms from geometric mixing rule
# No /omp style for force computation currently active
# Neighbor list info ...
#   update: every = 1 steps, delay = 0 steps, check = yes
#   max neighbors/atom: 2000, page size: 100000
#   master list distance cutoff = 0.00068898816
#   ghost atom cutoff = 0.00068898816
#   binsize = 0.00034449408, bins = 59 59 59
#   1 neighbor lists, perpetual/occasional/extra = 1 0 0
#   (1) pair lj/cut, perpetual
# ...

# %% [markdown]
# ## Run compression with moving walls
# Here it seems the speed of the wall is set to be too fast. the `temp` result increases dramastically.

# %%
return_code = subprocess.call(['mpirun', '-np', '4', 'lmp_mpi', '-pk', 'omp', '4', '-in', 'compress.lmps'])
# Out:
# LAMMPS (2 Aug 2023)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:98)
#   using 1 OpenMP thread(s) per MPI task
# set 4 OpenMP thread(s) per MPI task
# using multi-threaded neighbor list subroutines
# Lattice spacing in x,y,z = 0.0002 0.0002 0.0002
# Reading data file ...
#   orthogonal box = (-0.01 -0.01 -0.01) to (0.01 0.01 0.01)
#   1 by 2 by 2 MPI processor grid
#   reading atoms ...
#   66325 atoms
#   reading velocities ...
#   66325 velocities
#   read_data CPU = 0.199 seconds
# System init for write_data ...
# Generated 0 of 0 mixed pair_coeff terms from geometric mixing rule
# No /omp style for force computation currently active
# Neighbor list info ...
#   update: every = 1 steps, delay = 0 steps, check = yes
#   max neighbors/atom: 2000, page size: 100000
#   master list distance cutoff = 0.00068898816
#   ghost atom cutoff = 0.00068898816
#   binsize = 0.00034449408, bins = 59 59 59
# ...

# %% [markdown]
# ![result-frame](./compression-result.png)
